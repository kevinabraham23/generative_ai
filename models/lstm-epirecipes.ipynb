# %% [markdown]
# #  LSTM on Recipe Data

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import json
import re
import string

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, losses

# %% [markdown]
# ##  Parameters <a name="parameters"></a>

# %%
VOCAB_SIZE = 10000
MAX_LEN = 200
EMBEDDING_DIM = 100
N_UNITS = 128
VALIDATION_SPLIT = 0.2
SEED = 42
LOAD_MODEL = False
BATCH_SIZE = 32
EPOCHS = 25

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("hugodarwood/epirecipes")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/epirecipes

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# List all GPUs
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(f"{len(gpus)} Physical GPUs, {len(logical_gpus)} Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## 1. Load the data <a name="load"></a>

# %%
# Load the full dataset
with open("/kaggle/input/epirecipes/full_format_recipes.json") as json_data:
    recipe_data = json.load(json_data)

# %%
# Filter the dataset
filtered_data = [
    "Recipe for " + x["title"] + " | " + " ".join(x["directions"])
    for x in recipe_data
    if "title" in x
    and x["title"] is not None
    and "directions" in x
    and x["directions"] is not None
]

# %%
# Count the recipes
n_recipes = len(filtered_data)
print(f"{n_recipes} recipes loaded")
# Out:
# 20111 recipes loaded

# %%
example = filtered_data[9]
print(example)
# Out:
# Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas  | Chop enough parsley leaves to measure 1 tablespoon; reserve. Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan, covered, 5 minutes. Meanwhile, sprinkle gelatin over water in a medium bowl and let soften 1 minute. Strain broth through a fine-mesh sieve into bowl with gelatin and stir to dissolve. Season with salt and pepper. Set bowl in an ice bath and cool to room temperature, stirring. Toss ham with reserved parsley and divide among jars. Pour gelatin on top and chill until set, at least 1 hour. Whisk together mayonnaise, mustard, vinegar, 1/4 teaspoon salt, and 1/4 teaspoon pepper in a large bowl. Stir in celery, cornichons, and potatoes. Pulse peas with marjoram, oil, 1/2 teaspoon pepper, and 1/4 teaspoon salt in a food processor to a coarse mash. Layer peas, then potato salad, over ham.

# %% [markdown]
# ## 2. Tokenise the data

# %%
# Pad the punctuation, to treat them as separate 'words'
def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}])", r" \1 ", s)
    s = re.sub(" +", " ", s)
    return s


text_data = [pad_punctuation(x) for x in filtered_data]

# %%
# Display an example of a recipe
example_data = text_data[9]
example_data
# Out:
# 'Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas | Chop enough parsley leaves to measure 1 tablespoon ; reserve . Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan , covered , 5 minutes . Meanwhile , sprinkle gelatin over water in a medium bowl and let soften 1 minute . Strain broth through a fine - mesh sieve into bowl with gelatin and stir to dissolve . Season with salt and pepper . Set bowl in an ice bath and cool to room temperature , stirring . Toss ham with reserved parsley and divide among jars . Pour gelatin on top and chill until set , at least 1 hour . Whisk together mayonnaise , mustard , vinegar , 1 / 4 teaspoon salt , and 1 / 4 teaspoon pepper in a large bowl . Stir in celery , cornichons , and potatoes . Pulse peas with marjoram , oil , 1 / 2 teaspoon pepper , and 1 / 4 teaspoon salt in a food processor to a coarse mash . Layer peas , then potato salad , over ham . '

# %%
# Convert to a Tensorflow Dataset
text_ds = (
    tf.data.Dataset.from_tensor_slices(text_data)
    .batch(BATCH_SIZE)
    .shuffle(1000)
)

# %%
# Create a vectorisation layer
vectorize_layer = layers.TextVectorization(
    standardize="lower",
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=MAX_LEN + 1,
)

# %%
# Adapt the layer to the training set
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()

# %%
# Display some token:word mappings
for i, word in enumerate(vocab[:10]):
    print(f"{i}: {word}")
# Out:
# 0:
# 1: [UNK]
# 2: .
# 3: ,
# 4: and
# 5: to
# 6: in
# 7: the
# 8: with
# 9: a

# %%
# Display the same example converted to ints
example_tokenised = vectorize_layer(example_data)
print(example_tokenised.numpy())
# Out:
# [  26   16  557    1    8  298  335  189    4 1054  494   27  332  228
#   235  262    5  594   11  133   22  311    2  332   45  262    4  671
#     4   70    8  171    4   81    6    9   65   80    3  121    3   59
#    12    2  299    3   88  650   20   39    6    9   29   21    4   67
#   529   11  164    2  320  171  102    9  374   13  643  306   25   21
#     8  650    4   42    5  931    2   63    8   24    4   33    2  114
#    21    6  178  181 1245    4   60    5  140  112    3   48    2  117
#   557    8  285  235    4  200  292  980    2  107  650   28   72    4
#   108   10  114    3   57  204   11  172    2   73  110  482    3  298
#     3  190    3   11   23   32  142   24    3    4   11   23   32  142
#    33    6    9   30   21    2   42    6  353    3 3224    3    4  150
#     2  437  494    8 1281    3   37    3   11   23   15  142   33    3
#     4   11   23   32  142   24    6    9  291  188    5    9  412  572
#     2  230  494    3   46  335  189    3   20  557    2    0    0    0
#     0    0    0    0    0]

# %% [markdown]
# ## 3. Create the Training Set

# %%
# Create the training set of recipes and the same text shifted by one word
def prepare_inputs(text):
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]
    return x, y


train_ds = text_ds.map(prepare_inputs)

# %% [markdown]
# ## 4. Build the LSTM <a name="build"></a>

# %%
inputs = layers.Input(shape=(None,), dtype="int32")
x = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(inputs)
x = layers.LSTM(N_UNITS, return_sequences=True)(x)
outputs = layers.Dense(VOCAB_SIZE, activation="softmax")(x)
lstm = models.Model(inputs, outputs)
lstm.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, None)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, None, 100)           │       1,000,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, None, 128)           │         117,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, None, 10000)         │       1,290,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,407,248 (9.18 MB)
#  Trainable params: 2,407,248 (9.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
if LOAD_MODEL:
    # model.load_weights('./models/model')
    lstm = models.load_model("./models/lstm", compile=False)

# %% [markdown]
# ## 5. Train the LSTM <a name="train"></a>

# %%
loss_fn = losses.SparseCategoricalCrossentropy()
lstm.compile("adam", loss_fn)

# %%
# Create a TextGenerator checkpoint
class TextGenerator(callbacks.Callback):
    def __init__(self, index_to_word, top_k=10):
        self.index_to_word = index_to_word
        self.word_to_index = {
            word: index for index, word in enumerate(index_to_word)
        }  # <1>

    def sample_from(self, probs, temperature):  # <2>
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [
            self.word_to_index.get(x, 1) for x in start_prompt.split()
        ]  # <3>
        sample_token = None
        info = []
        while len(start_tokens) < max_tokens and sample_token != 0:  # <4>
            x = np.array([start_tokens])
            y = self.model.predict(x, verbose=0)  # <5>
            sample_token, probs = self.sample_from(y[0][-1], temperature)  # <6>
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token)  # <7>
            start_prompt = start_prompt + " " + self.index_to_word[sample_token]
        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("recipe for", max_tokens=100, temperature=1.0)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.weights.h5",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")

# Tokenize starting prompt
text_generator = TextGenerator(vocab)

# %%
lstm.fit(
    train_ds,
    epochs=EPOCHS,
    callbacks=[model_checkpoint_callback, tensorboard_callback, text_generator],
)
# Out:
# Epoch 1/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.9857
# generated text:
# recipe for fat tomato | relish in discarding aluminum mushrooms , 30 - boil . mussels over large skillet on cup coarse sheets , about the 2 minutes , toast cream 12 to salt . drain in juice until second very inch tender in dumplings .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - loss: 4.9844
# Epoch 2/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.0444
# generated text:
# recipe for agnolotti and mussels | preheat oven to 375°f . butter together cream like rack in pan of oil . ( barley shortbread pancake and cut garlic ahead and coriander , leaving 1 / 2 weeks of paper of fork ; discard salsa leaf . arrange beef and brush legs from heat and leaving each ends with pan broth . press potato wide and reserve kitchen parfait overnight ; toss until pearl dry , about 2 minutes . simmer , dividing pieces . preheat to 400°f . discard large salted dried almonds , cut each slices into cilantro at
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - loss: 3.0439
# Epoch 3/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.5007
# generated text:
# recipe for onion and spice phyllo salsa tips | preheat oven to 400°f . salt in a large bowl . fit flour 9 inches and by 8 / 2 hours . remove dry pans , skillet . place onion , shallots , tomatillos , and 1 / 2 tsp . butter 2 tablespoons sugar in large saucepan . stir dressing and sauté until thickened and turn meat , about 3 times about 2 minutes . add cakes over small cocktail .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - loss: 2.5006
# Epoch 4/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.2496
# generated text:
# recipe for radicchio , yogurt , and sour cream pastor | dip the rice lengthwise they very paris . if you hold trough does not drain . of the potatoes warm water around pan and knead over direct - slides fat from skin as serving . let stand 30 minutes , until slightly charred , mushrooms is 155°f , about 2 minutes . in a medium saucepan combine the tomato and 2 tbsp , parsley , sun - sugar , ground hearts , wine , and minced milk to a low ) and bring to a boil , stirring .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 2.2495
# Epoch 5/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.0948
# generated text:
# recipe for coddled almonds and dipped vinaigrette | wash the tofu in the sheets of the olive seasoning and insides with the dressing seems the paste while making watermelon . into a 5 - inch kettle with remaining 8 tablespoons olive oil .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - loss: 2.0947
# Epoch 6/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.9980
# generated text:
# recipe for new smoked chicken giblet on broiled green white | heat strips and 1 tablespoon in medium bowl , then transfer to a large bowl . let stand 10 minutes . remove foil . place dandy cut into 1 / 2 - inch - diameter rectangles . place top and sides of bacon in center , then drape over breast of eggplant , leaving at 1 / 4 - inch dice . stir together eggs , and mint in medium bowl . beat butter ; flour in medium saucepan . add butter ; sauté until heated through , about
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 1.9979
# Epoch 7/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.9176
# generated text:
# recipe for indian figs and cherry sandwiches with yogurt and oysters | 1 hour and onions and 1 / 2 teaspoon if the sauce is deep - very marbled is soft , , divide 1 / 2 - ounce glazed tomatoes between several towels to release cloth . let sit at time until good pink , about 5 minutes . set aside . in a large casserole or kettle boil , swirling 3 minutes , and season with salt . vinegar , mix in yogurt and salt . grated tomatoes in foil , tossing to processor . chill , covered
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - loss: 1.9176
# Epoch 8/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.8635
# generated text:
# recipe for carrot papaya carpaccio with raspberry - bean vinaigrette | put mason - mesh sieve potato into a 4 - inch shallow and then cool . ( about 17 by homemade sinews , bring rice to a boil . ) 2 total of each tomato - tomato skillet may be slightly reduced , its surface , about 10 minutes and drain . add butter and granulated sugar in a saucepan over medium heat , then spread half of bread into 1 / 2 cup over a 2 - cup . stir and leave gently in an oiled nutlike area
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 1.8635
# Epoch 9/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.8277
# generated text:
# recipe for rice soup with italian vegetables | heat the oven to a bare simmer over low heat to avoid scorching , 2 to 10 minutes . blend in a quick - to potatoes , cook , uncovered , 20 minutes ( hydrate , to dissolve any cooking ) . ) blend in herbs . pour stalk and cream evenly over . sprinkle to lemon crumbs . increase oven temperature to 350°f . heat 1 tablespoon oil in a skillet over medium - high heat . add tomatoes , salt , and thyme to skillet and cook , covered ,
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - loss: 1.8277
# Epoch 10/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.7798
# generated text:
# recipe for classic vanilla pie | add cinnamon 1 / 2 cup water , jalapeño and butter up ; deep truffles in bowl . holding sheet of plastic crush , with pastry wheel , using grate pastry on several large round of parchment . bring dough will be lukewarm in heavy large saucepan over moderate heat . reduce heat and simmer until reduced to 10 minutes . increase heat to medium - low . add butter and stir 1 minute . mix in raisins and next 2 cups . add cranberries ; using kitchen shears , process in flour mixture
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 1.7798
# Epoch 11/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.7456
# generated text:
# recipe for sweet - berries , toasted raita | 1 . prepare grill for direct - heat cooking . remove meatballs from pot and cool slightly . meanwhile , place celery cheese , garlic and salt in a small bowl ; season with salt . do not pound scallops until tomatoes are just tender , about 5 minutes . transfer to a large bowl and set aside . meanwhile , muddle garlic and scallions with raw onions , then salt and pepper and onions in a large shallow heavy pot . simmer mixture , covered , until peppers are tender
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 1.7456
# Epoch 12/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.7213
# generated text:
# recipe for chicken lentil soup with position and mushrooms | if using pasta becomes extremely pungent longer is very shrimp , rinse cool . drain and rinse well . reserve garlic . place squash on beets in bowl and toss with enough dressing to coat . arrange 4 tablespoons whole garlic and generous generous 1 / 2 cup watercress on each skewer . place garlic in medium bowl ; season with salt and pepper . stir beets with almonds . cut yolks into 1 / 4 - inch - thick medallions . transfer phyllo peel and then peel . place
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 1.7213
# Epoch 13/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.6932
# generated text:
# recipe for tomatillo bourbon sauce | finely mango , chop 1 / 2 cup milk and curaçao in a bowl . reserve 1 / 2x2 1 / 2 cups cream and slice in one fourth of onion and pecans . cook bacon in a large skillet over medium heat , stirring , until brown and cooked through , 4 to 2 minutes on each side . run a knife in one , reduce heat until smooth , about 1 / 2 or up a 5 - - to 5 - 5 ingredients . roll pan in a meaty bag 1
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - loss: 1.6932
# Epoch 14/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.6674
# generated text:
# recipe for asparagus and celery cappellacci with white spiced chiles | cook cider in a small pot of boiling salted water until tender , about 15 minutes . in a deep bowl stir together spinach , soy sauce , curry powder , vinegar , and salt and pepper to taste until combined . season with salt and pepper and serve .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 22s 36ms/step - loss: 1.6675
# Epoch 15/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.6520
# generated text:
# recipe for spices with dried seafood , jelly , and tarragon vinaigrette | place and close foil . generously fava black pepper , garlic , and kefir paste in oil . heat a wok over high heat just until softened , a shade darker , then transfer pan to a large bowl and let cool completely , about 1 hour . transfer to a large bowl and cook , onion , and chile in microwave 12 minutes , or until dough forms . pluck out into outer portions of each of a double flesh ; discard lid . brush turkey
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - loss: 1.6520
# Epoch 16/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.6497
# generated text:
# recipe for [UNK] beet salad | mix beets , garlic , cumin , olive oil , cilantro , celery , and caraway seeds in 2 tablespoon marinara dressing to blend again . stir in broth . transfer to small bowl . sprinkle with extra - virgin olive oil . sprinkle with buttermilk .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - loss: 1.6497
# Epoch 17/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.6238
# generated text:
# recipe for fresh mozzarella with shallots and sausage diagonally | combine all ingredients in a blender until smooth . wrap with parmesan and roast to 400°f . heat a dry small skillet or dutch oven over moderate heat . let cool and crumble over quesadillas . dip a eggs in half and pour in warm water to reach evenly get enough to hold the liquids . broil half of bread cakes until just cooked through . transfer cake to a baking tin and broil on a broiler pan about 2 to 3 minutes , and splay in upper and lower
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - loss: 1.6238
# Epoch 18/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.6142
# generated text:
# recipe for black snapper with artichokes and radishes | heat oil in a 10 - inch heavy skillet over moderate heat until hot but not smoking , then sauté remaining 5 3 / 4 tablespoons butter in skillet over medium heat until it begins to brown in color , about 20 seconds more . transfer to paper towels to drain . whisk together all apple ingredients over pasta . add shrimp and cook for 30 seconds ; add sour cream , dill , mace , and remaining ingredients in a small bowl and let stand 20 minutes . spoon some
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 1.6142
# Epoch 19/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.5964
# generated text:
# recipe for green beans with pecorino and pine nuts | finely chop potatoes in processor . add lemon juice and half at coarse ; season with salt . ( can be made 1 day ahead . cover ; chill . ) combine pineapple , shrimp , orange peel , garlic , garlic , and ginger in heavy large bowl ; blend cheese mixture and shallot mixture until mixture holds together . mix in 1 grape salsa in small bowl to mix . coat mustard in oil . drain well . season dressing with salt and pepper . ( can be
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 1.5964
# Epoch 20/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.5881
# generated text:
# recipe for tuna sates with garlicky nuts and goat cheese | sprinkle eggplant with 1 tablespoon vinegar with half - roasted tomatoes in large bowl ; toss with oregano . combine tuna , carrots , 1 teaspoon red bell pepper sprigs , and pepper in small bowl . rub oil over large metal bowl . mix in milk and thyme , then chickpea - salad salad . refrigerate . prepare barbecue ( medium heat ) . add oil ( total ) and meatballs . arrange chicken and gill side up , and vegetables and dip in dish . turn off
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - loss: 1.5881
# Epoch 21/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.5682
# generated text:
# recipe for panfried eggplant , parmesan , and raisin salad | mash beets with 1 tablespoon oil in a blender until finely chopped . pour vinaigrette over all over sauce , scraping up browned bits , and squeeze out excess marinade . reserve steaks , using a fork , and set aside . brush tuna over fish , letting excess drip off . toss dressing , cut sides down and turn to a broiler . prepare grill for several hours on cutting board . cut each half into 1 - inch pieces . with a serrated knife halve onion lengthwise
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 1.5683
# Epoch 22/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.5631
# generated text:
# recipe for gremolata | combine first 5 ingredients in heavy small saucepan and bring to boil over medium - high heat . simmer until reduced to reduced , about 3 minutes to cool . ( can be prepared 2 days ahead . cover and keep refrigerated . ) ladle drained prosciutto 1 teaspoon each tortilla into 2 - inch lengths . cover and refrigerate up to 1 day . whisk sugar , lime juice and 1 / 2 cup sugar in heavy medium saucepan . whisk over medium heat until well blended . cool . season with salt and pepper
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 1.5631
# Epoch 23/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.5503
# generated text:
# recipe for baked eggs with buttermilk dijon vinaigrette | whisk eggs , oil , and 1 teaspoon salt in medium bowl ; whisk to blend . gradually mix in oil . pour off top ; line bottoms with parchment paper . roll out 1 dough disk on lightly floured surface to six 5 - inch round . fit dough into 2 - inch ribbon ( do not pierce pan bottom and pan bottom , pressing firmly to distribute into bottom . ) press dough onto carefully with standing next quadrant of 12 , baking dish . butter baking sheet (
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 1.5503
# Epoch 24/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.5440
# generated text:
# recipe for grilled swordfish with rosemary raita | prepare steaks to prepare a knife . prepare baking . fill two 2 - quart shallow roasting pan with brisket and sprinkle with salt . if stir with a fork if needed , add peanuts and chile seeds and season with salt and pepper . spoon cranberry relish over to high . marinate lamb , covered and chilled , at least 2 hours , or up to 2 days .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - loss: 1.5440
# Epoch 25/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.5331
# generated text:
# recipe for roasted eggplant and radishes | preheat oven to 350°f . whisk oil ; season with salt . do ahead : can be made 1 day ahead . cover and chill . place plums in hot sealable bags layer . combine apples , lemon , whole thyme , and 1 / 2 cup sugar in a small bowl ; cover and let stand until cracked to soft . transfer to a rimmed baking sheet . wrap outside package on widest part , up to make sundaes ( have up some left ) , and scoop at a rim .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - loss: 1.5331

# %%
# !mkdir models
# Out:
# /usr/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %%
# Save the final model
lstm.save("./models/lstm.keras")

# %% [markdown]
# ## 6. Generate text using the LSTM

# %%
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
        print("--------\n")

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=10, temperature=1.0
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 4 cup

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 2:   	40.11%
# 4:   	33.92%
# 3:   	14.52%
# 8:   	8.01%
# 1:   	0.5%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4
# cup:   	82.9%
# of:   	6.85%
# inch:   	3.5%
# -:   	3.13%
# pounds:   	0.39%
# --------

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=10, temperature=0.2
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 2 cup

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 2:   	69.49%
# 4:   	30.06%
# 3:   	0.43%
# 8:   	0.02%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2
# cup:   	100.0%
# -:   	0.0%
# of:   	0.0%
# inch:   	0.0%
# pounds:   	0.0%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=7, temperature=1.0
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | whisk
#
#
# PROMPT: recipe for chocolate ice cream |
# whisk:   	17.57%
# combine:   	13.95%
# in:   	8.12%
# beat:   	7.7%
# bring:   	5.13%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=7, temperature=0.2
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | whisk
#
#
# PROMPT: recipe for chocolate ice cream |
# whisk:   	73.71%
# combine:   	23.22%
# in:   	1.55%
# beat:   	1.19%
# bring:   	0.16%
# --------
